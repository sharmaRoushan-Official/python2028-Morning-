# %% [markdown]
# ## 9. Function in python

# %% [markdown]
# ## 1. What is a Function?
#
# ####  ✅ Definition:
#  * __A `Function` is a reusable block of code that perform a specific tasks.__
#
# #### ✅ Why we use functions?
#  * Avoid code repetation
#  * Meke code reusable
#  * Imporve modularity
#  * Easier dubugging
#  * Resuablity

# %% [markdown]
# #### 🟢 Creating a function
#
# ✅ Syntax

# %%
# def function_name():
    # blcok of code 


# function_name()  # function call

# %%
def greet():
    print("Hello, Welcome to Python")

# %%
greet()
# Out:
# Hello, Welcome to Python

# %%
greet()
# Out:
# Hello, Welcome to Python

# %%
def greetName(name):  # name is parameter of the function
    greetMsg = "Congratulations! "+ name
    return greetMsg

greetName("Ruchika") # arguments
# Out:
# 'Congratulations! Ruchika'

# %% [markdown]
# ## 🟢 Function with Return Value
#
# #### ✅ `return` statement

# %%
def add(a,b): # a, b is parameter
    return a+b

result = add(10,5)
result
# Out:
# 15

# %%
add(100,15)
# Out:
# 115

# %%
add(-45,50)
# Out:
# 5

# %%
add(-78,-50)
# Out:
# -128

# %% [markdown]
# ###  🟢 Types of Function with arguments
#
# 1️⃣ Positional Arguments

# %%
def student(name,age):
    print(name,age)

student("Yash",65)
# Out:
# Yash 65

# %% [markdown]
# 2️⃣ Keyword Arugments

# %%
def student(name,age):
    print(name,age)


student(age=65,name="Yash")
# Out:
# Yash 65

# %% [markdown]
# 3️⃣ Default Arguments

# %%
def greet(name="Kushal"): # name = "Kushal"
    return "congratulations! "+name

greet("Anil")
# Out:
# 'congratulations! Anil'

# %%
greet()
# Out:
# 'congratulations! Kushal'

# %%
greet("Vishal")
# Out:
# 'congratulations! Vishal'

# %%
greet("Ruchika")
# Out:
# 'congratulations! Ruchika'

# %%
greet()
# Out:
# 'congratulations! Kushal'

# %% [markdown]
# ### 4️⃣ Variable Length Arguments
# ✅ *args(Non-keyword variable arguments)

# %%
def total(*numbers):
    print(sum(numbers))

total(10)
# Out:
# 10

# %%
total(10,20)
# Out:
# 30

# %%
total(10,20,-30)
# Out:
# 0

# %%
total(10,20,-30,90)
# Out:
# 90

# %%
total(10,20,-30,78,99)
# Out:
# 177

# %% [markdown]
# ### 🟢 Types of Function
#
# 1️⃣ Built-in Functions
#
# * Sum() - Sum or iterable.
# * abs()- Absolute value
# * round()- Round a number
# * pow()- power(x^y)
# * len()- total size of element
# * type()- check data type of element
# * print()- display value on screen
# * min()- smallest value
# * max()- largest value
# * int()- convert to integer
# * float()- convert to float
# * str()- convert to string
# * bool()- convert to boolean
# * list()- convert to list
# * tuple()- convert to tuple
# * set()- convert to set
# * dict()- convert to dictionary
# * chr()- ASCII to character
# * ord()- chraracter to ASCII
# * hex()- convert to Hexadecimal
# * bin()- convert to binary
# * oct()- convert to octal
# * sorted()- return sorted list
# * reversed() -  Reverse iterator
# * enumerate()- add index to iterable
# * zip() - comibine iterables
# * map()- apply function to iterable
# * filter()- filter elements
# * all()- True if all elements are ture.
# * any()- True if any element is true
# * input() -  take user input
# * id() - get object ID
# * isistance() - check type
# * issubclass()- check subclass
# * dir()- list attribute
# * help()- help documentation
# * collable()- check if callable
# * hasattar()- check attribute
# * getattar() -  get attribute
# * delattar() - delete attribute
# * setattar() -  set attribute
# * range()- generate sequecne
# * open()- open file
# * format()-  format string
# * eval() -  Evaluate expression
# * exec() -  Execute code
# * gloabls() -  global symbol
# * locals() -  local symbol table
# * compile() -  compile source code
# * memoryview() -  memory view object
# * import()-  to call external library

# %%
ord("A")
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
bin(45)
# Out:
# '0b101101'

# %%
hex(10)
# Out:
# '0xa'

# %%
oct(5)
# Out:
# '0o5'

# %%
bin(45)
# Out:
# '0b101101'

# %%
oct(45)
# Out:
# '0o55'

# %%
bin(78)
# Out:
# '0b1001110'

# %%
oct(78)
# Out:
# '0o116'

# %% [markdown]
# 2️⃣ User -defined Functions
#
# Functions created by user.

# %%
# Write a function to take two parameter from user and find the greatest one.


# write a funtion to take parameter fron user and find the greatest one.

def greatest_num(a, b):
    c = max(a, b)
    return c

greatest_num(1,4)
# Out:
# 4

# %%
def get_greatnumber(a,b):
    
     if a>b:
         print("Greatest value is:",a)
     else :
         print("Smallest Value is:",b)
get_greatnumber(a=40,b=20)
# Out:
# Greatest value is: 40

# %%
def maxNum():
    x=int(input("enter the value of x:"))
    y=int(input("enter the value of y:"))
    if x<y:
        print(f"{y} is greater than {x}")
    else:
         print(f"{x} is greater than {y}")
maxNum()
# Out:
# enter the value of x: 78
# enter the value of y: 96
# 96 is greater than 78

# %% [markdown]
# ## 🟢 Scope of Variables
