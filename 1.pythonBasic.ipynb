# %% [markdown]
# # Python Baisc

# %%
"Hello world"
# Out:
# 'Hello world'

# %%
# Hello world
# how to check version of python in this cells 

import sys  # system
print(sys.version)
# Out:
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
# two types of quotes
# ''
# ""

print("Hello world")
# Out:
# Hello world

# %%
print('Hello world')
# Out:
# Hello world

# %%
# string :
print('Hello world')
print("Hello world")
print("1000")  # string
print('True')
print("False")
# Out:
# Hello world
# Hello world
# 1000
# True
# False

# %%
1000
# Out:
# 1000

# %%
# Numbers  integer, float

# 1 integer
print(100)
print(1256)
print(7800)
print(10000)
# Out:
# 100
# 1256
# 7800
# 10000

# %%
# float

print(100.0)
print(0.11)
print(1256.23)
print(7800.56)
print(10000.0)
# Out:
# 100.0
# 0.11
# 1256.23
# 7800.56
# 10000.0

# %%
# Boolean: True-1/False-0
print(True)
print(False)
# Out:
# True
# False

# %%
print("true")
# Out:
# true

# %%
print(float(True))
print(float(False))
# Out:
# 1.0
# 0.0

# %%
# Data typecasting 

num = 100

# %%
num
# Out:
# 100

# %%
num = 1000

# %%
num
# Out:
# 1000

# %%
num1 = 100

# %%
num
# Out:
# 1000

# %%
num1
# Out:
# 100

# %%
num = 100
print(num,type(num))
# Out:
# 100 <class 'int'>

# %%
# type() keyword

# %%
print("Hello world")
print(type('Hello world'))

print('1000')
print(type('1000'))


# number

print(1000)
print(type(1000))


# float
print(100.23)
print(type(100.23))


# boolean
print(True)
print(type(True))

print(False)
print(type(False))
# Out:
# Hello world
# <class 'str'>
# 1000
# <class 'str'>
# 1000
# <class 'int'>
# 100.23
# <class 'float'>
# True
# <class 'bool'>
# False
# <class 'bool'>

# %%
# Data Typecasting

num = 100
print(num,type(num))


# string 
num2 = str(num)
print(num2,type(num2))


# 
num3 = 100.23  # float  # string
print(num3,type(num3))
# Out:
# 100 <class 'int'>
# 100 <class 'str'>
# 100.256 <class 'str'>

# %%
# eval()

num1 = "100"
print(num1,type(num1))


num2 = eval(num1)
print(num2,type(num2))
# Out:
# 100 <class 'str'>
# 100 <class 'int'>

# %%
num1 = "100.23"
print(num1,type(num1))


num2 = eval(num1)
print(num2,type(num2))
# Out:
# 100.23 <class 'str'>
# 100.23 <class 'float'>

# %%
num1 = "True"
print(num1,type(num1))

num2 = eval(num1)
print(num2,type(num2))
# Out:
# True <class 'str'>
# True <class 'bool'>

# %%
num1 = "False"
print(num1,type(num1))


num2 = eval(num1)
print(num2,type(num2))
# Out:
# False <class 'str'>
# False <class 'bool'>

# %%
num3 =str(num3)
print(num3, type(num3))
# Out:
# 100.256 <class 'str'>

# %%
# Let's convert the booleans to an integer, a float, and a string.

bool_1 = True
print("Original Value is:",bool_1)
print("Original Value data type:",type(bool_1))

# integer
print(int(bool_1))
print(type(int(bool_1)))

#float
print(float(bool_1))
print(type(float(bool_1)))

# string
print(str(bool_1))
print(type(str(bool_1)))
# Out:
# Original Value is: True
# Original Value data type: <class 'bool'>
# 1
# <class 'int'>
# 1.0
# <class 'float'>
# True
# <class 'str'>

# %%
bool_2 = False

# %%
# Let's find the data types of 9/3 and 9//4

print(9/3)
print(type(9/3))
# Out:
# 3.0
# <class 'float'>

# %%
print(9//4)
print(type(9//3))
# Out:
# 2
# <class 'int'>

# %%
# Expression and Variables

# Addition

x = 56+65-88+10*5
print(x)
print(type(x))
# Out:
# 83
# <class 'int'>

# %%
# substractions

x = 85-52-25-10
print(x,type(x))
# Out:
# -2 <class 'int'>

# %%
# Multiplication

x = 85*25*56

print(x,type(x))
# Out:
# 119000 <class 'int'>

# %%
# Division

x = 125/24  # Actual Division
print(x,type(x))
# Out:
# 5.208333333333333 <class 'float'>

# %%
x = 125//24   # floor division
print(x,type(x))
# Out:
# 5 <class 'int'>

# %%
# Modulus: remainder value

x = 125%24
print(x)
# Out:
# 5

# %%
x = 3%2
print(x)
# Out:
# 1

# %%
# Exponent
  
x = 2**2  # 2x2 = 4
print(x)
# Out:
# 4

# %%
x = 5**3  # 5x5x5 =  125
print(x,type(x))
# Out:
# 125 <class 'int'>

# %%
# Operators in Python 

# 1. Arithematic Operators = [+,-,*,/,//,%,**]
#     >> 1. Uniary Operator- [++,--]
#     >> 2. Binary operator- [+,-,*,/,//,%]
# 2. Comparision Operator/Relative Operator- [<,>,<=,>=,==,!=]
# 3. Logical Operator - [AND, OR, NOT]
# 4. Identity Operator - [is or is not]
# 5. Membership Operator - [in or not in]
# 6. Assignment Opertor - [=]

# %%
# i= 5
# i++;


# 5+2
# Out:
# 7

# %%
# Variables

number = 90
print(number)
# Out:
# 90

# %%
number1 = 900.0
print(number,type(number1))
# Out:
# 900.0 <class 'float'>

# %%
id(number)
# Out:
# 2530086537488

# %%
id(number1)
# Out:
# 2530086538000
