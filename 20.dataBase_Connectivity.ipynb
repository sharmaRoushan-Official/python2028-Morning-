# %% [markdown]
# ### 20. Database Connectivity
#
# ### SQL Connectivity and CRUD Operations
#
# (python+Database)

# %% [markdown]
# ## 1️⃣ What is MySQL Connectivity?
#
# * `MySQL Connectivity means:`
#  __Connecting  a Python Program to a MySQL database to store, retrieve, update and delete data.__
#
#
# ## 📌 Used In:
#  * __Web Applications__
#  * __Django/Flask backend__
#  * __Desktop Applications__
#  * __Real-time systems__
#
#
# ## 2️⃣ What is CRUD?
#
# | Operation | SQL | Meaning |
# |---|---|---|
# |Create|INSERT|Add new record|
# |Read|SELECT|Fetch data|
# |Update|UPDATE| Modify data|
# |Delete|DELETE|Remove data|

# %% [markdown]
# ## 3️⃣ Requirements
#
# ✅ Software Needed
#  * Python Installed
#  * MySQL Server
#  * MySQL Workbench(Optional)
#
# ✅ Python Library

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector as c

# %%
conn = c.connect(
    host = "localhost",
    user = 'root',
    password = '123456789',
    
)

# %%
cursor = conn.cursor()
print("Connected to MySQL")

cursor.execute("CREATE DATABASE school")
# Out:
# Connected to MySQL
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Can't create database 'school'; database exists
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[4], line 4
#       1 cursor = conn.cursor()
# ...

# %%
cursor.execute("USE School")

# %%
cursor.execute("CREATE TABLE STUDENT(ID INT AUTO_INCREMENT PRIMARY KEY, NAME VARCHAR(100), MARKS INT)")
print("Table Created")

# %%
cursor.execute("DESCRIBE student")
for i in cursor:
    print(i)
# Out:
# ('ID', 'int', 'NO', 'PRI', None, 'auto_increment')
# ('NAME', 'varchar(100)', 'YES', '', None, '')
# ('MARKS', 'int', 'YES', '', None, '')

# %%
if conn.is_connected():
    print("connected Succesfully!!")
# Out:
# connected Succesfully!!

# %% [markdown]
# # Create
# ##  Insert Single Record

# %%
query = "INSERT INTO student (id,name,marks) VALUES (%s,%s,%s)"
data = (101,"Rahul",85)
cursor.execute(query,data)
conn.commit()
print("Record Inserted")
# Out:
# Record Inserted

# %%
cursor.execute("SELECT * FROM STUDENT")

# %%
for j in cursor:
    print(j)
# Out:
# (101, 'Rahul', 85)

# %% [markdown]
# ### Notes:
# * `conn` -> Connection object
# * `cursor` --> execute SQL Queries

# %% [markdown]
# ## Create Table
